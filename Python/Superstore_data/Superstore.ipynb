# %%
# Importing libraries for analysis
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Reading excel dataset into a dataframe
store_data = pd.read_excel("C:/Users/NARENDRAN/Downloads/Sample - Superstore.xlsx", parse_dates=True, index_col="Row ID")
store_data
# Out:
# C:\Users\NARENDRAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\NARENDRAN\AppData\Local\Temp\ipykernel_5500\2252941796.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   store_data = pd.read_excel("C:/Users/NARENDRAN/Downloads/Sample - Superstore.xlsx", parse_dates=True, index_col="Row ID")
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 3       CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 4       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# ...                ...        ...        ...             ...         ...
# 9990    CA-2017-110422 2017-01-21 2017-01-23    Second Class    TB-21400
# 9991    CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 9992    CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 9993    CA-2020-121258 2020-02-26 2020-03-03  Standard Class    DB-13060
# 9994    CA-2020-119914 2020-05-04 2020-05-09    Second Class    CC-12220
#
#            Customer Name    Segment Country/Region             City  \
# Row ID
# 1            Claire Gute   Consumer  United States        Henderson
# 2            Claire Gute   Consumer  United States        Henderson
# 3        Darrin Van Huff  Corporate  United States      Los Angeles
# 4         Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5         Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...                  ...        ...            ...              ...
# 9990    Tom Boeckenhauer   Consumer  United States            Miami
# 9991         Dave Brooks   Consumer  United States       Costa Mesa
# 9992         Dave Brooks   Consumer  United States       Costa Mesa
# 9993         Dave Brooks   Consumer  United States       Costa Mesa
# 9994        Chris Cortes   Consumer  United States      Westminster
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# 1         Kentucky      42420.0  South  FUR-BO-10001798        Furniture
# 2         Kentucky      42420.0  South  FUR-CH-10000454        Furniture
# 3       California      90036.0   West  OFF-LA-10000240  Office Supplies
# 4          Florida      33311.0  South  FUR-TA-10000577        Furniture
# 5          Florida      33311.0  South  OFF-ST-10000760  Office Supplies
# ...            ...          ...    ...              ...              ...
# 9990       Florida      33180.0  South  FUR-FU-10001889        Furniture
# 9991    California      92627.0   West  FUR-FU-10000747        Furniture
# 9992    California      92627.0   West  TEC-PH-10003645       Technology
# 9993    California      92627.0   West  OFF-PA-10004041  Office Supplies
# 9994    California      92683.0   West  OFF-AP-10002684  Office Supplies
#
#        Sub-Category                                       Product Name  \
# Row ID
# 1         Bookcases                  Bush Somerset Collection Bookcase
# 2            Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 3            Labels  Self-Adhesive Address Labels for Typewriters b...
# 4            Tables      Bretford CR4500 Series Slim Rectangular Table
# 5           Storage                     Eldon Fold 'N Roll Cart System
# ...             ...                                                ...
# 9990    Furnishings                             Ultra Door Pull Handle
# 9991    Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
# 9992         Phones                              Aastra 57i VoIP phone
# 9993          Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"
# 9994     Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
#            Sales  Quantity  Discount    Profit
# Row ID
# 1       261.9600         2      0.00   41.9136
# 2       731.9400         3      0.00  219.5820
# 3        14.6200         2      0.00    6.8714
# 4       957.5775         5      0.45 -383.0310
# 5        22.3680         2      0.20    2.5164
# ...          ...       ...       ...       ...
# 9990     25.2480         3      0.20    4.1028
# 9991     91.9600         2      0.00   15.6332
# 9992    258.5760         2      0.20   19.3932
# 9993     29.6000         4      0.00   13.3200
# 9994    243.1600         2      0.00   72.9480
#
# [9994 rows x 20 columns]

# %%
# Ensuring floats do not appear in scientific notation
pd.set_option("display.float_format", lambda x: '%.2f' % x)

# %% [markdown]
# # Data Cleaning

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9994 non-null   object
#  1   Order Date      9994 non-null   datetime64[ns]
#  2   Ship Date       9994 non-null   datetime64[ns]
#  3   Ship Mode       9994 non-null   object
#  4   Customer ID     9994 non-null   object
#  5   Customer Name   9994 non-null   object
#  6   Segment         9994 non-null   object
#  7   Country/Region  9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Postal Code     9983 non-null   float64
#  11  Region          9994 non-null   object
#  12  Product ID      9994 non-null   object
#  13  Category        9994 non-null   object
#  14  Sub-Category    9994 non-null   object
#  15  Product Name    9994 non-null   object
#  16  Sales           9994 non-null   float64
#  17  Quantity        9994 non-null   int64
#  18  Discount        9994 non-null   float64
#  19  Profit          9994 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(13)
# memory usage: 1.6+ MB

# %%
# Number of rows and columns
store_data.shape
# Out:
# (9994, 20)

# %%
# Checking for duplicates
store_data.duplicated()
# Out:
# Row ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# 9994    False
# Length: 9994, dtype: bool

# %%
# Checking for duplicates
store_data[store_data.duplicated()]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 3407    US-2017-150119 2017-04-23 2017-04-27  Standard Class    LB-16795
#
#          Customer Name      Segment Country/Region      City State  \
# Row ID
# 3407    Laurel Beltran  Home Office  United States  Columbus  Ohio
#
#         Postal Code Region       Product ID   Category Sub-Category  \
# Row ID
# 3407       43229.00   East  FUR-CH-10002965  Furniture       Chairs
#
#                                              Product Name  Sales  Quantity  \
# Row ID
# 3407    Global Leather Highback Executive Chair with P... 281.37         2
#
#         Discount  Profit
# Row ID
# 3407        0.30  -12.06

# %%
# Dropping duplicates
store_data.drop_duplicates(inplace = True)

# %%
# Confirming that duplicated row(s) was dropped
store_data[store_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Checking for nulls
store_data.isna().sum()
# Out:
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
#checking the null values
store_data[store_data["Postal Code"].isna() ==True]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 2235    CA-2020-104066 2020-12-05 2020-12-10  Standard Class    QJ-19255
# 5275    CA-2018-162887 2018-11-07 2018-11-09    Second Class    SV-20785
# 8799    US-2019-150140 2019-04-06 2019-04-10  Standard Class    VM-21685
# 9147    US-2019-165505 2019-01-23 2019-01-27  Standard Class    CB-12535
# 9148    US-2019-165505 2019-01-23 2019-01-27  Standard Class    CB-12535
# 9149    US-2019-165505 2019-01-23 2019-01-27  Standard Class    CB-12535
# 9387    US-2020-127292 2020-01-19 2020-01-23  Standard Class    RM-19375
# 9388    US-2020-127292 2020-01-19 2020-01-23  Standard Class    RM-19375
# 9389    US-2020-127292 2020-01-19 2020-01-23  Standard Class    RM-19375
# 9390    US-2020-127292 2020-01-19 2020-01-23  Standard Class    RM-19375
# 9742    CA-2018-117086 2018-11-08 2018-11-12  Standard Class    QJ-19255
#
#            Customer Name      Segment Country/Region        City    State  \
# Row ID
# 2235        Quincy Jones    Corporate  United States  Burlington  Vermont
# 5275    Stewart Visinsky     Consumer  United States  Burlington  Vermont
# 8799     Valerie Mitchum  Home Office  United States  Burlington  Vermont
# 9147    Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9148    Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9149    Claudia Bergmann    Corporate  United States  Burlington  Vermont
# 9387       Raymond Messe     Consumer  United States  Burlington  Vermont
# 9388       Raymond Messe     Consumer  United States  Burlington  Vermont
# 9389       Raymond Messe     Consumer  United States  Burlington  Vermont
# 9390       Raymond Messe     Consumer  United States  Burlington  Vermont
# 9742        Quincy Jones    Corporate  United States  Burlington  Vermont
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 2235            NaN   East  TEC-AC-10001013       Technology  Accessories
# 5275            NaN   East  FUR-CH-10000595        Furniture       Chairs
# 8799            NaN   East  TEC-PH-10002555       Technology       Phones
# 9147            NaN   East  TEC-AC-10002926       Technology  Accessories
# 9148            NaN   East  OFF-AR-10003477  Office Supplies          Art
# 9149            NaN   East  OFF-ST-10001526  Office Supplies      Storage
# 9387            NaN   East  OFF-PA-10000157  Office Supplies        Paper
# 9388            NaN   East  OFF-PA-10001970  Office Supplies        Paper
# 9389            NaN   East  OFF-AP-10000828  Office Supplies   Appliances
# 9390            NaN   East  OFF-EN-10001509  Office Supplies    Envelopes
# 9742            NaN   East  FUR-BO-10004834        Furniture    Bookcases
#
#                                              Product Name   Sales  Quantity  \
# Row ID
# 2235          Logitech ClearChat Comfort/USB Headset H390  205.03         7
# 5275                      Safco Contoured Stacking Chairs  715.20         3
# 8799                  Nortel Meridian M5316 Digital phone 1294.75         5
# 9147                Logitech Wireless Marathon Mouse M705   99.98         2
# 9148                                    4009 Highlighters    8.04         6
# 9149                Iceberg Mobile Mega Data/Printer Cart 1564.29        13
# 9387                                            Xerox 191   79.92         4
# 9388                                           Xerox 1881   12.28         1
# 9389                      Avanti 4.4 Cu. Ft. Refrigerator  542.94         3
# 9390                            Poly String Tie Envelopes    2.04         1
# 9742    Riverside Palais Royal Lawyers Bookcase, Royal... 4404.90         5
#
#         Discount  Profit
# Row ID
# 2235        0.00   67.66
# 5275        0.00  178.80
# 8799        0.00  336.63
# 9147        0.00   42.99
# 9148        0.00    2.73
# 9149        0.00  406.72
# 9387        0.00   37.56
# 9388        0.00    5.77
# 9389        0.00  152.02
# 9390        0.00    0.96
# 9742        0.00 1013.13

# %%
# changing the column names
store_data.rename(columns = {
    "Order ID" : "order_id",
    "Order Date": "order_date",
    "Ship Date": "ship_date",
    "Ship Mode": "ship_mode",
    "Customer ID": "customer_id",
    "Customer Name": "customer_name",
    "Segment": "segment",
    "Country/Region": "country",
    "City": "city",
    "State": "state",
    "Postal Code": "postal_code",
    "Region": "region",
    "Product ID": "product_id",
    "Category": "category",
    "Sub-Category": "sub_category",
    "Product Name": "product_name",
    "Sales": "sales",
    "Quantity": "quantity",
    "Discount": "discount",
    "Profit": "profit"
}, inplace = True)

# %%
# Confirming changes were made
store_data.head()
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 1       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 3       CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 4       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#           customer_name    segment        country             city  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              state  postal_code region       product_id         category  \
# Row ID
# 1         Kentucky     42420.00  South  FUR-BO-10001798        Furniture
# 2         Kentucky     42420.00  South  FUR-CH-10000454        Furniture
# 3       California     90036.00   West  OFF-LA-10000240  Office Supplies
# 4          Florida     33311.00  South  FUR-TA-10000577        Furniture
# 5          Florida     33311.00  South  OFF-ST-10000760  Office Supplies
#
#        sub_category                                       product_name  sales  \
# Row ID
# 1         Bookcases                  Bush Somerset Collection Bookcase 261.96
# 2            Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,... 731.94
# 3            Labels  Self-Adhesive Address Labels for Typewriters b...  14.62
# 4            Tables      Bretford CR4500 Series Slim Rectangular Table 957.58
# 5           Storage                     Eldon Fold 'N Roll Cart System  22.37
#
#         quantity  discount  profit
# Row ID
# 1              2      0.00   41.91
# 2              3      0.00  219.58
# 3              2      0.00    6.87
# 4              5      0.45 -383.03
# 5              2      0.20    2.52

# %% [markdown]
# # Sales Overview: What is the total sales revenue generated by the Superstore?

# %%
total_sales = store_data["sales"].sum()
total_sales
# Out:
# np.float64(2296919.4883000003)

# %%
store_data["sales"]
# Out:
# Row ID
# 1      261.96
# 2      731.94
# 3       14.62
# 4      957.58
# 5       22.37
#         ...
# 9990    25.25
# 9991    91.96
# 9992   258.58
# 9993    29.60
# 9994   243.16
# Name: sales, Length: 9993, dtype: float64

# %% [markdown]
# # Mean Value in the total sales

# %%
store_data["sales"].mean()
# Out:
# np.float64(229.8528458220755)

# %%
profit = store_data["profit"].sum()
profit
# Out:
# np.float64(286409.0805)

# %%
store_data.sort_values(by="profit", ascending =False).head(3)
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 6827    CA-2019-118689 2019-10-02 2019-10-09  Standard Class    TC-20980
# 8154    CA-2020-140151 2020-03-23 2020-03-25     First Class    RB-19360
# 4191    CA-2020-166709 2020-11-17 2020-11-22  Standard Class    HL-15040
#
#        customer_name    segment        country       city       state  \
# Row ID
# 6827    Tamara Chand  Corporate  United States  Lafayette     Indiana
# 8154    Raymond Buch   Consumer  United States    Seattle  Washington
# 4191    Hunter Lopez   Consumer  United States     Newark    Delaware
#
#         postal_code   region       product_id    category sub_category  \
# Row ID
# 6827       47905.00  Central  TEC-CO-10004722  Technology      Copiers
# 8154       98115.00     West  TEC-CO-10004722  Technology      Copiers
# 4191       19711.00     East  TEC-CO-10004722  Technology      Copiers
#
#                                  product_name    sales  quantity  discount  \
# Row ID
# 6827    Canon imageCLASS 2200 Advanced Copier 17499.95         5      0.00
# 8154    Canon imageCLASS 2200 Advanced Copier 13999.96         4      0.00
# 4191    Canon imageCLASS 2200 Advanced Copier 10499.97         3      0.00
#
#         profit
# Row ID
# 6827   8399.98
# 8154   6719.98
# 4191   5039.99

# %% [markdown]
# store_data["category"].unique()

# %%
store_data.groupby("category")[["sales","profit"]].sum()
# Out:
#                     sales    profit
# category
# Furniture       741718.42  18463.33
# Office Supplies 719047.03 122490.80
# Technology      836154.03 145454.95

# %%
store_data.groupby("category")[["sales","profit"]].mean()
# Out:
#                  sales  profit
# category
# Furniture       349.87    8.71
# Office Supplies 119.32   20.33
# Technology      452.71   78.75

# %% [markdown]
# # Number of unique sub-categories of products in the Superstore dataset?

# %%
store_data["sub_category"].nunique()
# Out:
# 17

# %%
store_data.groupby("customer_name")["order_id"].nunique().sort_values(ascending = False).to_frame().head(5)
# Out:
#                   order_id
# customer_name
# Emily Phan              17
# Sally Hughsby           13
# Noel Staavos            13
# Patrick Gardner         13
# Zuschuss Carroll        13

# %% [markdown]
# # What are the earliest and latest order dates in the dataset.

# %%
store_data[store_data["order_date"]== store_data["order_date"].min()]
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 7981    CA-2017-103800 2017-01-03 2017-01-07  Standard Class    DP-13000
#
#         customer_name   segment        country     city  state  postal_code  \
# Row ID
# 7981    Darren Powers  Consumer  United States  Houston  Texas     77095.00
#
#          region       product_id         category sub_category  \
# Row ID
# 7981    Central  OFF-PA-10000174  Office Supplies        Paper
#
#                                              product_name  sales  quantity  \
# Row ID
# 7981    Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.45         2
#
#         discount  profit
# Row ID
# 7981        0.20    5.55

# %%
store_data[store_data["order_date"] == store_data["order_date"].max()]
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 646     CA-2020-126221 2020-12-30 2021-01-05  Standard Class    CC-12430
# 907     CA-2020-143259 2020-12-30 2021-01-03  Standard Class    PO-18865
# 908     CA-2020-143259 2020-12-30 2021-01-03  Standard Class    PO-18865
# 909     CA-2020-143259 2020-12-30 2021-01-03  Standard Class    PO-18865
# 1297    CA-2020-115427 2020-12-30 2021-01-03  Standard Class    EB-13975
# 1298    CA-2020-115427 2020-12-30 2021-01-03  Standard Class    EB-13975
# 5092    CA-2020-156720 2020-12-30 2021-01-03  Standard Class    JM-15580
#
#             customer_name      segment        country           city  \
# Row ID
# 646           Chuck Clark  Home Office  United States       Columbus
# 907     Patrick O'Donnell     Consumer  United States  New York City
# 908     Patrick O'Donnell     Consumer  United States  New York City
# 909     Patrick O'Donnell     Consumer  United States  New York City
# 1297           Erica Bern    Corporate  United States      Fairfield
# 1298           Erica Bern    Corporate  United States      Fairfield
# 5092        Jill Matthias     Consumer  United States       Loveland
#
#              state  postal_code   region       product_id         category  \
# Row ID
# 646        Indiana     47201.00  Central  OFF-AP-10002457  Office Supplies
# 907       New York     10009.00     East  FUR-BO-10003441        Furniture
# 908       New York     10009.00     East  TEC-PH-10004774       Technology
# 909       New York     10009.00     East  OFF-BI-10003684  Office Supplies
# 1297    California     94533.00     West  OFF-BI-10002103  Office Supplies
# 1298    California     94533.00     West  OFF-BI-10004632  Office Supplies
# 5092      Colorado     80538.00     West  OFF-FA-10003472  Office Supplies
#
#        sub_category                                       product_name  sales  \
# Row ID
# 646      Appliances  Eureka The Boss Plus 12-Amp Hard Box Upright V... 209.30
# 907       Bookcases  Bush Westfield Collection Bookcases, Fully Ass... 323.14
# 908          Phones                          Gear Head AU3700S Headset  90.93
# 909         Binders               Wilson Jones Legal Size Ring Binders  52.78
# 1297        Binders    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl  13.90
# 1298        Binders                                 GBC Binding covers  20.72
# 5092      Fasteners                                Bagged Rubber Bands   3.02
#
#         quantity  discount  profit
# Row ID
# 646            2      0.00   56.51
# 907            4      0.20   12.12
# 908            7      0.00    2.73
# 909            3      0.20   19.79
# 1297           2      0.20    4.52
# 1298           2      0.20    6.47
# 5092           3      0.20   -0.60

# %% [markdown]
# # What are the average sales amounts for transactions with a discount and without a discount separately?

# %%
def apply_discount(row):
    if row["discount"] == 0:
        return "No"
    else:
        return "Yes"

store_data["discounted"] = store_data.apply(apply_discount , axis="columns")

store_data.head()
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 1       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 3       CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 4       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#           customer_name    segment        country             city  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              state  ...  region       product_id         category  \
# Row ID              ...
# 1         Kentucky  ...   South  FUR-BO-10001798        Furniture
# 2         Kentucky  ...   South  FUR-CH-10000454        Furniture
# 3       California  ...    West  OFF-LA-10000240  Office Supplies
# 4          Florida  ...   South  FUR-TA-10000577        Furniture
# 5          Florida  ...   South  OFF-ST-10000760  Office Supplies
#
#        sub_category                                       product_name  sales  \
# Row ID
# 1         Bookcases                  Bush Somerset Collection Bookcase 261.96
# 2            Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,... 731.94
# 3            Labels  Self-Adhesive Address Labels for Typewriters b...  14.62
# 4            Tables      Bretford CR4500 Series Slim Rectangular Table 957.58
# 5           Storage                     Eldon Fold 'N Roll Cart System  22.37
#
#         quantity  discount  profit  discounted
# Row ID
# 1              2      0.00   41.91          No
# 2              3      0.00  219.58          No
# 3              2      0.00    6.87          No
# 4              5      0.45 -383.03         Yes
# 5              2      0.20    2.52         Yes
#
# [5 rows x 21 columns]

# %%
average_sales = store_data.groupby("discounted")["sales"].mean()
average_sales
# Out:
# discounted
# No    226.74
# Yes   232.73
# Name: sales, dtype: float64

# %% [markdown]
# # What are the total sales and profits for each region.

# %%
store_data.groupby("region")[["sales" , "profit"]].sum().sort_values(by ="sales" ,ascending =False)
# Out:
#             sales    profit
# region
# West    725457.82 108418.45
# East    678499.87  91534.84
# Central 501239.89  39706.36
# South   391721.91  46749.43

# %% [markdown]
# # Adding a shipping duration for further analysis

# %%
store_data["shipping_duration(days)"] = store_data["ship_date"] - store_data["order_date"]
store_data.head()
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 1       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 3       CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 4       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#           customer_name    segment        country             city  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              state  ...       product_id         category sub_category  \
# Row ID              ...
# 1         Kentucky  ...  FUR-BO-10001798        Furniture    Bookcases
# 2         Kentucky  ...  FUR-CH-10000454        Furniture       Chairs
# 3       California  ...  OFF-LA-10000240  Office Supplies       Labels
# 4          Florida  ...  FUR-TA-10000577        Furniture       Tables
# 5          Florida  ...  OFF-ST-10000760  Office Supplies      Storage
#
#                                              product_name  sales quantity  \
# Row ID
# 1                       Bush Somerset Collection Bookcase 261.96        2
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,... 731.94        3
# 3       Self-Adhesive Address Labels for Typewriters b...  14.62        2
# 4           Bretford CR4500 Series Slim Rectangular Table 957.58        5
# 5                          Eldon Fold 'N Roll Cart System  22.37        2
#
#         discount  profit  discounted  shipping_duration(days)
# Row ID
# 1           0.00   41.91          No                   3 days
# 2           0.00  219.58          No                   3 days
# 3           0.00    6.87          No                   4 days
# 4           0.45 -383.03         Yes                   7 days
# 5           0.20    2.52         Yes                   7 days
#
# [5 rows x 22 columns]

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 1 to 9994
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 9993 non-null   object
#  1   order_date               9993 non-null   datetime64[ns]
#  2   ship_date                9993 non-null   datetime64[ns]
#  3   ship_mode                9993 non-null   object
#  4   customer_id              9993 non-null   object
#  5   customer_name            9993 non-null   object
#  6   segment                  9993 non-null   object
#  7   country                  9993 non-null   object
#  8   city                     9993 non-null   object
#  9   state                    9993 non-null   object
#  10  postal_code              9982 non-null   float64
#  11  region                   9993 non-null   object
#  12  product_id               9993 non-null   object
#  13  category                 9993 non-null   object
#  14  sub_category             9993 non-null   object
#  15  product_name             9993 non-null   object
#  16  sales                    9993 non-null   float64
#  17  quantity                 9993 non-null   int64
#  18  discount                 9993 non-null   float64
#  19  profit                   9993 non-null   float64
#  20  discounted               9993 non-null   object
#  21  shipping_duration(days)  9993 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), float64(4), int64(1), object(14), timedelta64[ns](1)
# memory usage: 1.8+ MB

# %%
# Converting to a string so the number and days could be separated
store_data["shipping_duration(days)"] = store_data["shipping_duration(days)"].astype(str)

# %%
# Splitting the number and days to extract the number alone
store_data["shipping_duration(days)"] = store_data["shipping_duration(days)"].str.split(" ").str.get(0)

# %%
store_data.head()
# Out:
#               order_id order_date  ship_date       ship_mode customer_id  \
# Row ID
# 1       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 2       CA-2019-152156 2019-11-08 2019-11-11    Second Class    CG-12520
# 3       CA-2019-138688 2019-06-12 2019-06-16    Second Class    DV-13045
# 4       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
# 5       US-2018-108966 2018-10-11 2018-10-18  Standard Class    SO-20335
#
#           customer_name    segment        country             city  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              state  ...       product_id         category sub_category  \
# Row ID              ...
# 1         Kentucky  ...  FUR-BO-10001798        Furniture    Bookcases
# 2         Kentucky  ...  FUR-CH-10000454        Furniture       Chairs
# 3       California  ...  OFF-LA-10000240  Office Supplies       Labels
# 4          Florida  ...  FUR-TA-10000577        Furniture       Tables
# 5          Florida  ...  OFF-ST-10000760  Office Supplies      Storage
#
#                                              product_name  sales quantity  \
# Row ID
# 1                       Bush Somerset Collection Bookcase 261.96        2
# 2       Hon Deluxe Fabric Upholstered Stacking Chairs,... 731.94        3
# 3       Self-Adhesive Address Labels for Typewriters b...  14.62        2
# 4           Bretford CR4500 Series Slim Rectangular Table 957.58        5
# 5                          Eldon Fold 'N Roll Cart System  22.37        2
#
#         discount  profit  discounted  shipping_duration(days)
# Row ID
# 1           0.00   41.91          No                        3
# 2           0.00  219.58          No                        3
# 3           0.00    6.87          No                        4
# 4           0.45 -383.03         Yes                        7
# 5           0.20    2.52         Yes                        7
#
# [5 rows x 22 columns]

# %% [markdown]
# # What are the unique shipping modes available in the Superstore dataset?

# %%
store_data["ship_mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
store_data.groupby("ship_mode")["sales"].sum()
# Out:
# ship_mode
# First Class       351428.42
# Same Day          128363.12
# Second Class      459193.57
# Standard Class   1357934.37
# Name: sales, dtype: float64

# %%
store_data["shipping_duration(days)"] = store_data["shipping_duration(days)"].astype(int)
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 1 to 9994
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 9993 non-null   object
#  1   order_date               9993 non-null   datetime64[ns]
#  2   ship_date                9993 non-null   datetime64[ns]
#  3   ship_mode                9993 non-null   object
#  4   customer_id              9993 non-null   object
#  5   customer_name            9993 non-null   object
#  6   segment                  9993 non-null   object
#  7   country                  9993 non-null   object
#  8   city                     9993 non-null   object
#  9   state                    9993 non-null   object
#  10  postal_code              9982 non-null   float64
#  11  region                   9993 non-null   object
#  12  product_id               9993 non-null   object
#  13  category                 9993 non-null   object
#  14  sub_category             9993 non-null   object
#  15  product_name             9993 non-null   object
#  16  sales                    9993 non-null   float64
#  17  quantity                 9993 non-null   int64
#  18  discount                 9993 non-null   float64
#  19  profit                   9993 non-null   float64
#  20  discounted               9993 non-null   object
#  21  shipping_duration(days)  9993 non-null   int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(14)
# memory usage: 1.8+ MB

# %% [markdown]
# # What are the average shipping durations for each mode

# %%
store_data.groupby("ship_mode")["shipping_duration(days)"].mean()
# Out:
# ship_mode
# First Class      2.18
# Same Day         0.04
# Second Class     3.24
# Standard Class   5.01
# Name: shipping_duration(days), dtype: float64

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ## Total Sales Over Time

# %%
# Querying the data to get total sales for each day

# %%
sales_over_time = store_data.groupby("order_date")["sales"].sum().reset_index()
sales_over_time.head()
# Out:
#   order_date   sales
# 0 2017-01-03   16.45
# 1 2017-01-04  288.06
# 2 2017-01-05   19.54
# 3 2017-01-06 4407.10
# 4 2017-01-07   87.16

# %%
# Plotting a line chart for sales over time

# %%
plt.figure(figsize=(16,8))
plt.title("Total Sales Over Time")
sns.lineplot(x="order_date" , y="sales" , data =sales_over_time)
plt.xlabel("Order Date")
plt.ylabel("Total Sales")
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ## Total Profits Over Time

# %%
# Querying the data to get total profits for each day
profits_over_time = store_data.groupby("order_date")["profit"].sum().reset_index()
profits_over_time.head()
# Out:
#   order_date  profit
# 0 2017-01-03    5.55
# 1 2017-01-04  -65.99
# 2 2017-01-05    4.88
# 3 2017-01-06 1358.05
# 4 2017-01-07  -71.96

# %%
# Plotting a line chart showing profits over time
plt.figure(figsize=(16,8))
plt.title("Total Profits Over Time")
sns.lineplot(x="order_date", y="profit", data=profits_over_time)
plt.xlabel("Order Date")
plt.ylabel("Total Profits")
# Out:
# Text(0, 0.5, 'Total Profits')

# %% [markdown]
# ## Order count for each Ship Mode

# %%
# Extracting the order count for each ship mode
shipmode_order_count = store_data.groupby("ship_mode")["order_id"].nunique().reset_index(name="order_count")
shipmode_order_count
# Out:
#         ship_mode  order_count
# 0     First Class          787
# 1        Same Day          264
# 2    Second Class          964
# 3  Standard Class         2994

# %%
# Plotting a bar chart to show order count
plt.figure(figsize=(8,6))
sns.barplot(x="ship_mode", y="order_count", data=shipmode_order_count,palette='deep')
plt.title("Order Count By Ship Mode")
plt.xlabel("Ship Mode")
plt.ylabel("Order Count")
# Out:
# C:\Users\NARENDRAN\AppData\Local\Temp\ipykernel_5500\3574965240.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="ship_mode", y="order_count", data=shipmode_order_count,palette='deep')
# Text(0, 0.5, 'Order Count')

# %% [markdown]
# ## Top 10 Customers - Total Money Spent(Sales)

# %%
# Querying for the top 10 customers who spent the most money
customer_sales = store_data.groupby("customer_name")["sales"].sum().sort_values(ascending = False).reset_index()
top10_customers = customer_sales.head(10)
top10_customers
# Out:
#         customer_name    sales
# 0         Sean Miller 25043.05
# 1        Tamara Chand 19052.22
# 2        Raymond Buch 15117.34
# 3        Tom Ashbrook 14595.62
# 4       Adrian Barton 14473.57
# 5        Ken Lonsdale 14175.23
# 6        Sanjit Chand 14142.33
# 7        Hunter Lopez 12873.30
# 8        Sanjit Engle 12209.44
# 9  Christopher Conant 12129.07

# %%
# Plotting a horizontal bar to display that data
plt.figure(figsize=(12,6))
sns.barplot(x="sales" , y="customer_name" , data =top10_customers,palette='deep')
plt.title("Top 10 Customers By Amount Spent")
plt.xlabel("Customer Name")
plt.ylabel("Total Sales");
# Out:
# C:\Users\NARENDRAN\AppData\Local\Temp\ipykernel_5500\602616131.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="sales" , y="customer_name" , data =top10_customers,palette='deep')

# %% [markdown]
# ## Most Orders by Customers

# %%
# Extracting the customers with the most orders
customer_order_count = store_data.groupby("customer_name")["order_id"].nunique().sort_values(ascending=False).reset_index(name='order_count')
top_orders = customer_order_count.head(15)
top_orders
# Out:
#           customer_name  order_count
# 0            Emily Phan           17
# 1         Sally Hughsby           13
# 2          Noel Staavos           13
# 3       Patrick Gardner           13
# 4      Zuschuss Carroll           13
# 5            Joel Eaton           13
# 6         Erin Ashbrook           13
# 7   Chloris Kastensmidt           13
# 8        Suzanne McNair           12
# 9          Rick Bensley           12
# 10         Resi Pölking           12
# 11            Pete Kriz           12
# 12            Ken Black           12
# 13       Bill Donatelli           12
# 14         Bart Pistole           12

# %%
# Bar Chart showing the top 20 with the most orders
plt.figure(figsize=(10,6))
sns.barplot(x="customer_name", y="order_count", data=top_orders ,hue ="customer_name", palette='colorblind')
plt.title("Top 15 Customers By Number of Orders")
plt.xlabel("Customer Name")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# ## Total Sales By Segment

# %%
# Querying for the total sales for each segment
segment_sales = store_data.groupby("segment")["sales"].sum()
segment_sales
# Out:
# segment
# Consumer      1161401.34
# Corporate      706146.37
# Home Office    429371.78
# Name: sales, dtype: float64

# %%
# Pie Chart Showing how much each Segment contributes to total sales generated
plt.figure(figsize=(7,7))
plt.pie(segment_sales , labels = segment_sales.index , autopct='%1.1f%%', startangle=90)
plt.title('Contribution of Segments To Total Sales');

# %% [markdown]
# ## Segment Sales By Category

# %%
# Querying the data for total sales of each segment broken into categories
segment_cat_sales = store_data.groupby(["segment","category"])["sales"].sum().reset_index()
segment_cat_sales
# Out:
#        segment         category     sales
# 0     Consumer        Furniture 391049.31
# 1     Consumer  Office Supplies 363952.14
# 2     Consumer       Technology 406399.90
# 3    Corporate        Furniture 229019.79
# 4    Corporate  Office Supplies 230676.46
# 5    Corporate       Technology 246450.12
# 6  Home Office        Furniture 121649.33
# 7  Home Office  Office Supplies 124418.43
# 8  Home Office       Technology 183304.02

# %%
# Plotting a bar chart to display the data
plt.figure(figsize=(10,6))
sns.barplot(x="segment", y="sales", hue="category", data=segment_cat_sales)
plt.title("Total Sales For Each Segment")
plt.xlabel("Segment")
plt.ylabel("Total Sales")
# Out:
# Text(0, 0.5, 'Total Sales')

# %% [markdown]
# ## Total Sales For Each State

# %%
# Querying for the sales for each state
state_sales = store_data.groupby("state")["sales"].sum().sort_values(ascending=False).reset_index()
state_sales
# Out:
#                    state     sales
# 0             California 457687.63
# 1               New York 310876.27
# 2                  Texas 170188.05
# 3             Washington 138641.27
# 4           Pennsylvania 116511.91
# 5                Florida  89473.71
# 6               Illinois  80166.10
# 7                   Ohio  77976.76
# 8               Michigan  76269.61
# 9               Virginia  70636.72
# 10        North Carolina  55603.16
# 11               Indiana  53555.36
# 12               Georgia  49095.84
# 13              Kentucky  36591.75
# 14            New Jersey  35764.31
# 15               Arizona  35282.00
# 16             Wisconsin  32114.61
# 17              Colorado  32108.12
# 18             Tennessee  30661.87
# 19             Minnesota  29863.15
# 20         Massachusetts  28634.43
# 21              Delaware  27451.07
# 22              Maryland  23705.52
# 23          Rhode Island  22627.96
# 24              Missouri  22205.15
# 25              Oklahoma  19683.39
# 26               Alabama  19510.64
# 27                Oregon  17431.15
# 28                Nevada  16729.10
# 29           Connecticut  13384.36
# 30              Arkansas  11678.13
# 31                  Utah  11220.06
# 32           Mississippi  10771.34
# 33             Louisiana   9217.03
# 34               Vermont   8929.37
# 35        South Carolina   8481.71
# 36              Nebraska   7464.93
# 37         New Hampshire   7292.52
# 38               Montana   5589.35
# 39            New Mexico   4783.52
# 40                  Iowa   4579.76
# 41                 Idaho   4382.49
# 42                Kansas   2914.31
# 43  District of Columbia   2865.02
# 44               Wyoming   1603.14
# 45          South Dakota   1315.56
# 46                 Maine   1270.53
# 47         West Virginia   1209.82
# 48          North Dakota    919.91

# %%
# Bar chart displaying the data
plt.figure(figsize=(16,8))
sns.barplot(y="sales", x="state", data=state_sales,hue="state")
plt.title("Total Sales For Each State")
plt.xlabel("State")
plt.ylabel("Total Sales")
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# ## Total Profits From Each State

# %%
# Querying for the profits earned from each state
state_profits = store_data.groupby("state")["profit"].sum().sort_values(ascending=False).reset_index()
state_profits
# Out:
#                    state    profit
# 0             California  76381.39
# 1               New York  74038.55
# 2             Washington  33402.65
# 3               Michigan  24463.19
# 4               Virginia  18597.95
# 5                Indiana  18382.94
# 6                Georgia  16250.04
# 7               Kentucky  11199.70
# 8              Minnesota  10823.19
# 9               Delaware   9977.37
# 10            New Jersey   9772.91
# 11             Wisconsin   8401.80
# 12          Rhode Island   7285.63
# 13              Maryland   7031.18
# 14         Massachusetts   6785.50
# 15              Missouri   6436.21
# 16               Alabama   5786.83
# 17              Oklahoma   4853.96
# 18              Arkansas   4008.69
# 19           Connecticut   3511.49
# 20                Nevada   3316.77
# 21           Mississippi   3172.98
# 22                  Utah   2546.53
# 23               Vermont   2244.98
# 24             Louisiana   2196.10
# 25              Nebraska   2037.09
# 26               Montana   1833.33
# 27        South Carolina   1769.06
# 28         New Hampshire   1706.50
# 29                  Iowa   1183.81
# 30            New Mexico   1157.12
# 31  District of Columbia   1059.59
# 32                Kansas    836.44
# 33                 Idaho    826.72
# 34                 Maine    454.49
# 35          South Dakota    394.83
# 36          North Dakota    230.15
# 37         West Virginia    185.92
# 38               Wyoming    100.20
# 39                Oregon  -1190.47
# 40               Florida  -3399.30
# 41               Arizona  -3427.92
# 42             Tennessee  -5341.69
# 43              Colorado  -6527.86
# 44        North Carolina  -7490.91
# 45              Illinois -12607.89
# 46          Pennsylvania -15559.96
# 47                  Ohio -16959.32
# 48                 Texas -25729.36

# %%
# Bar chart displaying the data
plt.figure(figsize=(16,8))
sns.barplot(x="state",y="profit", data=state_profits,hue="state", palette='pastel')
plt.title("Total Profits Generated By Each State")
plt.xlabel("State")
plt.ylabel("Total Profits")
plt.xticks(rotation=45, ha='right');
