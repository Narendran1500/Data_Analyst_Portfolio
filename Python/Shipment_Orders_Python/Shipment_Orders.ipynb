# %%
import pandas as pd

# %%
# Reading excel dataset into a dataframe
ship_data = pd.read_excel('C:/Users/NARENDRAN/Downloads/Python/Shipment_orders_data/orders_data.xlsx')
ship_data
# Out:
#       Order Id Order Date       Ship Mode    Segment        Country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
ship_data.shape
# Out:
# (9994, 16)

# %%
ship_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   datetime64[ns]
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# ...

# %%
ship_data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
# considering the values of Not Available , unknown as na values
ship_data = pd.read_excel('C:/Users/NARENDRAN/Downloads/Python/Shipment_orders_data/orders_data.xlsx',na_values=['Not Available', 'unknown'])
ship_data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
ship_data.head()
# Out:
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
ship_data.rename(columns={"Order Id":"Order_Id",
                         "Order Date":"Order_Date",
                         "Ship Mode":"Ship_Mode",
                         "Postal Code":"Postal_Code",
                         "Sub Category":"Sub_Category",
                         "Product Id":"Product_Id",
                         "cost price":"Cost_Price",
                         "List Price":"List_Price",
                         "Discount Percent":"Discount_Percent"},inplace=True)
ship_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_Id          9994 non-null   int64
#  1   Order_Date        9994 non-null   datetime64[ns]
#  2   Ship_Mode         9988 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal_Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub_Category      9994 non-null   object
#  11  Product_Id        9994 non-null   object
#  12  Cost_Price        9994 non-null   int64
#  13  List_Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount_Percent  9994 non-null   int64
# ...

# %%
# adding a new column selling price
ship_data['Selling_Price']= ship_data['List_Price'] - ship_data['List_Price']*(ship_data['Discount_Percent']/100)
ship_data['Selling_Price']
# Out:
# 0       254.8
# 1       708.1
# 2         9.5
# 3       940.8
# 4        19.0
#         ...
# 9989     28.8
# 9990     86.4
# 9991    254.8
# 9992     29.1
# 9993    232.8
# Name: Selling_Price, Length: 9994, dtype: float64

# %%
ship_data.head(3)
# Out:
#    Order_Id Order_Date     Ship_Mode    Segment        Country         City  \
# 0         1 2023-03-01  Second Class   Consumer  United States    Henderson
# 1         2 2023-08-15  Second Class   Consumer  United States    Henderson
# 2         3 2023-01-10  Second Class  Corporate  United States  Los Angeles
#
#         State  Postal_Code Region         Category Sub_Category  \
# 0    Kentucky        42420  South        Furniture    Bookcases
# 1    Kentucky        42420  South        Furniture       Chairs
# 2  California        90036   West  Office Supplies       Labels
#
#         Product_Id  Cost_Price  List_Price  Quantity  Discount_Percent  \
# 0  FUR-BO-10001798         240         260         2                 2
# 1  FUR-CH-10000454         600         730         3                 3
# 2  OFF-LA-10000240          10          10         2                 5
#
#    Selling_Price
# 0          254.8
# 1          708.1
# 2            9.5

# %%
# adding profit column
ship_data['Profit']= ship_data['Selling_Price'] - ship_data['Cost_Price']
ship_data['Profit']
# Out:
# 0        14.8
# 1       108.1
# 2        -0.5
# 3       160.8
# 4        -1.0
#         ...
# 9989     -1.2
# 9990     16.4
# 9991     34.8
# 9992     -0.9
# 9993     22.8
# Name: Profit, Length: 9994, dtype: float64

# %%
ship_data.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Cost_Price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
# renaming the columns
ship_data.rename(columns={"Profit" : "Unit_Profit",
                         "Selling_Price" : "Unit_Selling_Price"},inplace= "True")
ship_data.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Cost_Price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
ship_data.dtypes
# Out:
# Order_Id                       int64
# Order_Date            datetime64[ns]
# Ship_Mode                     object
# Segment                       object
# Country                       object
# City                          object
# State                         object
# Postal_Code                    int64
# Region                        object
# Category                      object
# Sub_Category                  object
# Product_Id                    object
# Cost_Price                     int64
# List_Price                     int64
# Quantity                       int64
# Discount_Percent               int64
# Unit_Selling_Price           float64
# Unit_Profit                  float64
# dtype: object

# %% [markdown]
# # Dropping few columns

# %%
ship_data.drop(columns = ['Cost_Price','List_Price','Discount_Percent'],inplace=True)

# %%
ship_data.head()
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Quantity  Unit_Selling_Price  Unit_Profit
# 0    Bookcases  FUR-BO-10001798         2               254.8         14.8
# ...

# %%
ship_data['Total_Profit'] = ship_data['Quantity']*ship_data['Unit_Profit']
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit
# 0         2               254.8         14.8          29.6
# 1         3               708.1        108.1         324.3

# %%
# The below code connects to MYSQL and store a Pandas DataFrame into a MySQL database.

# %%
import sqlalchemy
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:NewStrongPassword@localhost:3306/newdatabase")

# %%
ship_data.to_sql('orders_data', con=engine , index=False, if_exists = 'replace')
# Out:
# 9994

# %% [markdown]
# # Questions
#
# ## Find top 10 highest profit generating products

# %%
ship_data.groupby('Product_Id')

# %%
ship_data.groupby('Product_Id')[['Total_Profit']].sum().sort_values(by = "Total_Profit", ascending =False).head(10)
# Out:
#                  Total_Profit
# Product_Id
# TEC-CO-10004722       24816.0
# TEC-MA-10002412       21746.4
# OFF-BI-10000545       17867.7
# TEC-CO-10001449       15948.0
# FUR-CH-10002024       13930.7
# OFF-BI-10003527       12792.9
# TEC-PH-10001459       11481.9
# TEC-MA-10000822       10102.3
# FUR-TA-10000198       10015.1
# TEC-MA-10001047        9989.0

# %% [markdown]
# ### Create a column for Total Sales value of each order

# %%
ship_data['Total_Sales'] = ship_data['Quantity'] * ship_data['Unit_Selling_Price']
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3

# %% [markdown]
# ### Find all orders from the 'Technology' category that were shipped using 'Second Class' ship mode, ordered by order date

# %%
filter_orders = ship_data[(ship_data['Category'] == 'Technology') & (ship_data['Ship_Mode'] == 'Second Class')]
filter_orders
# Out:
#       Order_Id Order_Date     Ship_Mode      Segment        Country  \
# 19          20 2022-01-11  Second Class     Consumer  United States
# 26          27 2022-02-08  Second Class     Consumer  United States
# 161        162 2023-11-27  Second Class     Consumer  United States
# 181        182 2022-06-25  Second Class    Corporate  United States
# 182        183 2022-01-10  Second Class  Home Office  United States
# ...        ...        ...           ...          ...            ...
# 9891      9892 2023-05-21  Second Class    Corporate  United States
# 9892      9893 2023-01-02  Second Class    Corporate  United States
# 9949      9950 2022-01-07  Second Class    Corporate  United States
# 9950      9951 2022-03-19  Second Class    Corporate  United States
# 9960      9961 2023-02-26  Second Class  Home Office  United States
#
#                City         State  Postal_Code   Region    Category  \
# 19    San Francisco    California        94109     West  Technology
# ...

# %%
sorted_orders = filter_orders.sort_values(by='Order_Date')
sorted_orders
# Out:
#       Order_Id Order_Date     Ship_Mode      Segment        Country  \
# 5420      5421 2022-01-01  Second Class     Consumer  United States
# 1087      1088 2022-01-04  Second Class    Corporate  United States
# 3271      3272 2022-01-05  Second Class    Corporate  United States
# 3526      3527 2022-01-06  Second Class  Home Office  United States
# 9949      9950 2022-01-07  Second Class    Corporate  United States
# ...        ...        ...           ...          ...            ...
# 2451      2452 2023-12-23  Second Class     Consumer  United States
# 2104      2105 2023-12-26  Second Class    Corporate  United States
# 1666      1667 2023-12-28  Second Class     Consumer  United States
# 8248      8249 2023-12-30  Second Class  Home Office  United States
# 5341      5342 2023-12-31  Second Class     Consumer  United States
#
#                City         State  Postal_Code   Region    Category  \
# 5420   Philadelphia  Pennsylvania        19134     East  Technology
# ...

# %% [markdown]
# ### Find the average Sales

# %%
import numpy as np
np.mean(ship_data['Total_Sales'])
# Out:
# np.float64(1108.5979787872725)

# %% [markdown]
# ### Find the city with the highest total quantity of products ordered.

# %%
ship_data.groupby('City')['Quantity'].sum().reset_index().sort_values(by=['Quantity'],ascending=False)
# Out:
#               City  Quantity
# 329  New York City      3417
# 266    Los Angeles      2879
# 374   Philadelphia      1981
# 438  San Francisco      1935
# 452        Seattle      1590
# ..             ...       ...
# 257    Lindenhurst         1
# 221        Jupiter         1
# 213      Iowa City         1
# 386    Port Orange         1
# 140         Elyria         1
#
# [531 rows x 2 columns]

# %% [markdown]
# ### Rank orders in each region by quantity in descending order

# %%
ship_data[['Region','Quantity']].sort_values(by=['Region','Quantity'],ascending=[True,False])
# Out:
#        Region  Quantity
# 660   Central        14
# 1045  Central        14
# 7387  Central        14
# 8074  Central        14
# 9515  Central        14
# ...       ...       ...
# 9752     West         1
# 9838     West         1
# 9902     West         1
# 9953     West         1
# 9986     West         1
#
# [9994 rows x 2 columns]

# %% [markdown]
# ### List all orders placed in the first quarter of any year (January to March), including the total cost for these orders

# %%
#create a column that only have month
ship_data['Month']= ship_data['Order_Date'].dt.month
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  Month
# 0         2               254.8         14.8          29.6        509.6      3
# 1         3               708.1        108.1         324.3       2124.3      8

# %%
ship_data[ship_data['Month'].isin([1,2,3,])]
# Out:
#       Order_Id Order_Date       Ship_Mode      Segment        Country  \
# 0            1 2023-03-01    Second Class     Consumer  United States
# 2            3 2023-01-10    Second Class    Corporate  United States
# 5            6 2022-03-13             NaN     Consumer  United States
# 7            8 2022-01-25  Standard Class     Consumer  United States
# 8            9 2023-03-23             NaN     Consumer  United States
# ...        ...        ...             ...          ...            ...
# 9963      9964 2022-01-17        Same Day     Consumer  United States
# 9966      9967 2022-02-21    Second Class    Corporate  United States
# 9973      9974 2023-03-07  Standard Class  Home Office  United States
# 9989      9990 2023-02-18    Second Class     Consumer  United States
# 9990      9991 2023-03-17  Standard Class     Consumer  United States
#
#               City         State  Postal_Code Region         Category  \
# ...

# %%
ship_data['Quarter'] = ship_data['Order_Date'].dt.quarter
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Quarter
# 0      3        1
# 1      8        3

# %%
ship_data['Year'] = ship_data['Order_Date'].dt.year
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Quarter  Year
# 0      3        1  2023
# 1      8        3  2023

# %%
temp_df = ship_data.groupby(['Year','Quarter'])[['Total_Sales']].sum().reset_index()
temp_df
# Out:
#    Year  Quarter  Total_Sales
# 0  2022        1    1275547.6
# 1  2022        2    1355326.7
# 2  2022        3    1343727.8
# 3  2022        4    1500939.2
# 4  2023        1    1559456.2
# 5  2023        2    1282878.4
# 6  2023        3    1308164.5
# 7  2023        4    1453287.8

# %%
temp_df[temp_df['Quarter']==1]
# Out:
#    Year  Quarter  Total_Sales
# 0  2022        1    1275547.6
# 4  2023        1    1559456.2

# %% [markdown]
# ### Find top 10 highest profit generating products

# %%
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Quarter  Year
# 0      3        1  2023
# 1      8        3  2023

# %%
ship_data.groupby('Product_Id')[['Total_Profit']].sum().reset_index().sort_values(by='Total_Profit',ascending=False).head(10)
# Out:
#            Product_Id  Total_Profit
# 1614  TEC-CO-10004722       24816.0
# 1642  TEC-MA-10002412       21746.4
# 657   OFF-BI-10000545       17867.7
# 1604  TEC-CO-10001449       15948.0
# 80    FUR-CH-10002024       13930.7
# 776   OFF-BI-10003527       12792.9
# 1724  TEC-PH-10001459       11481.9
# 1624  TEC-MA-10000822       10102.3
# 318   FUR-TA-10000198       10015.1
# 1630  TEC-MA-10001047        9989.0

# %% [markdown]
# ### Find top highest selling products in each region according to quantity

# %%
ship_data.groupby(['Region','Product_Id'])[['Quantity']].sum().reset_index().sort_values(by=['Region','Quantity'],ascending= [True,False])
# Out:
#        Region       Product_Id  Quantity
# 461   Central  OFF-BI-10000301        34
# 474   Central  OFF-BI-10000756        33
# 470   Central  OFF-BI-10000546        29
# 491   Central  OFF-BI-10001249        29
# 61    Central  FUR-CH-10002304        27
# ...       ...              ...       ...
# 5219     West  TEC-PH-10002185         1
# 5227     West  TEC-PH-10002447         1
# 5229     West  TEC-PH-10002483         1
# 5256     West  TEC-PH-10003357         1
# 5276     West  TEC-PH-10004120         1
#
# [5298 rows x 3 columns]

# %% [markdown]
# ### Total sales in each region

# %%
ship_data.groupby('Region')['Total_Sales'].sum().reset_index().sort_values(by='Total_Sales', ascending = False)
# Out:
#     Region  Total_Sales
# 3     West    3467409.6
# 1     East    3257983.8
# 0  Central    2387881.2
# 2    South    1966053.6

# %% [markdown]
# ### Top 5 highest selling products in each region according to sales

# %%
ship_data.sort_values(by=['Region', 'Total_Sales'], ascending=[True, False]).groupby('Region').head(5)\
[['Region', 'Product_Id', 'Total_Sales']] .reset_index()
# Out:
#     index   Region       Product_Id  Total_Sales
# 0    9039  Central  OFF-BI-10000545     122141.5
# 1    6826  Central  TEC-CO-10004722      84875.0
# 2     165  Central  TEC-MA-10000822      62668.8
# 3    4098  Central  OFF-BI-10001120      46305.0
# 4    8990  Central  TEC-CO-10003763      33271.0
# 5    4277     East  TEC-MA-10001047      61789.0
# 6    7666     East  TEC-CO-10001449      46656.0
# 7    2623     East  TEC-CO-10004722      43904.0
# 8    7243     East  FUR-CH-10002024      38586.6
# 9    6535     East  FUR-BO-10002213      38095.0
# 10   2697    South  TEC-MA-10002412     130406.4
# 11   4297    South  TEC-PH-10001459      53969.5
# 12   9639    South  FUR-TA-10000198      53105.0
# 13   8488    South  TEC-MA-10001127      42875.0
# 14    683    South  TEC-MA-10004125      31360.0
# 15   8153     West  TEC-CO-10004722      53760.0
# 16   1246     West  FUR-TA-10003473      42020.4
# 17    251     West  TEC-AC-10003832      41808.0
# ...

# %% [markdown]
# ### Find month over month growth comparison for 2022 and 2023

# %%
ship_data.head(2)
# Out:
#    Order_Id Order_Date     Ship_Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal_Code Region   Category Sub_Category       Product_Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total_Profit  Total_Sales  \
# 0         2               254.8         14.8          29.6        509.6
# 1         3               708.1        108.1         324.3       2124.3
#
#    Month  Quarter  Year
# 0      3        1  2023
# 1      8        3  2023

# %%
ship_pivot = ship_data.groupby(['Month','Year'])[['Total_Sales']].sum().reset_index().pivot_table(index='Month', columns='Year', values='Total_Sales', aggfunc='sum').reset_index()
ship_pivot
# Out:
# Year  Month      2022      2023
# 0         1  437431.3  434765.5
# 1         2  444011.1  731638.8
# 2         3  394105.2  393051.9
# 3         4  476400.9  543231.5
# 4         5  413625.5  410707.9
# 5         6  465300.3  328939.0
# 6         7  375278.4  422533.7
# 7         8  534562.4  465010.3
# 8         9  433887.0  420620.5
# 9        10  601707.8  626498.3
# 10       11  451809.6  334940.6
# 11       12  447421.8  491848.9

# %%
ship_pivot['YoY_growth']= ship_pivot[2022] - ship_pivot[2023]
ship_pivot
# Out:
# Year  Month      2022      2023  YoY_growth
# 0         1  437431.3  434765.5      2665.8
# 1         2  444011.1  731638.8   -287627.7
# 2         3  394105.2  393051.9      1053.3
# 3         4  476400.9  543231.5    -66830.6
# 4         5  413625.5  410707.9      2917.6
# 5         6  465300.3  328939.0    136361.3
# 6         7  375278.4  422533.7    -47255.3
# 7         8  534562.4  465010.3     69552.1
# 8         9  433887.0  420620.5     13266.5
# 9        10  601707.8  626498.3    -24790.5
# 10       11  451809.6  334940.6    116869.0
# 11       12  447421.8  491848.9    -44427.1

# %% [markdown]
# ### For each category which month had highest sales

# %%
monthly_sales = ship_data.groupby(['Month','Category'])[['Total_Sales']].sum().reset_index()
highest_sales_month = monthly_sales.loc[monthly_sales.groupby('Category')['Total_Sales'].idxmax()]
highest_sales_month
# Out:
#     Month         Category  Total_Sales
# 3       2        Furniture     409913.9
# 4       2  Office Supplies     445699.6
# 29     10       Technology     545987.2

# %%
ship_data.to_sql('orders_data', con=engine , index=False, if_exists = 'replace')
# Out:
# 9994

# %%
# Fetching the data from MYSQL

query = "SELECT * FROM orders_data"  # Fetch all data from 'orders_data' table

# Load data into Pandas DataFrame
df = pd.read_sql(query, con=engine)

print(df.head())
# Out:
#    Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  Quantity  Unit_Selling_Price  Unit_Profit  \
# 0    Bookcases  FUR-BO-10001798         2               254.8         14.8
# ...
